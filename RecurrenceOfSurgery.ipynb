# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font',family='Malgun Gothic')
import seaborn as sns
import pandas as pd
import scipy.stats as stats
import numpy as np

# %%
df_ROS = pd.read_csv('./datasets/RecurrenceOfSurgery.csv')
df_ROS[:2]
# Out:
#    Unnamed: 0 환자ID  Large Lymphocyte  Location of herniation   ODI  가족력  \
# 0           0  1PT              22.8                       3  51.0  0.0
# 1           1  2PT              44.9                       4  26.0  0.0
#
#    간질성폐질환  고혈압여부  과거수술횟수  당뇨여부  ...  Modic change    PI    PT  Seg Angle(raw)  \
# 0       0      0       0     0  ...             3  51.6  36.6            14.4
# 1       0      0       0     0  ...             0  40.8   7.2            17.8
#
#    Vaccum disc   골밀도  디스크단면적  디스크위치  척추이동척도  척추전방위증
# 0            0 -1.01  2048.5      4    Down       0
# 1            0 -1.14  1753.1      4      Up       0
#
# [2 rows x 52 columns]

# %%
df_ROSF=df_ROS[['Unnamed: 0', '환자ID', '신장', '체중', '연령', '성별', 'Large Lymphocyte',
       '우울증여부', '종양진행여부', '재발여부', '디스크단면적', '디스크위치', '척추이동척도', '척추전방위증',
       '수술시간', '수술실패여부', '수술기법', '흡연여부', 'Instability', '혈액형', '입원기간']]

# %%
df_ROSF
# Out:
#       Unnamed: 0    환자ID   신장    체중  연령  성별  Large Lymphocyte  우울증여부  종양진행여부  \
# 0              0     1PT  163  60.3  66   2              22.8      0       0
# 1              1     2PT  171  71.7  47   1              44.9      0       0
# 2              2     3PT  178  77.1  39   1              53.0      0       0
# 3              3     4PT  174  74.2  40   1              54.7      0       0
# 4              4     5PT  183  80.7  42   1              53.8      0       0
# ...          ...     ...  ...   ...  ..  ..               ...    ...     ...
# 1889        1889  1890PT  157  64.0  59   2              44.0      0       1
# 1890        1890  1891PT  157  59.0  42   2              30.8      0       0
# 1891        1891  1892PT  167  70.0  61   1              36.7      0       0
# 1892        1892  1893PT  177  77.0  29   1              32.5      0       0
# 1893        1893  1894PT  168  49.0  30   2              49.5      0       0
#
#       재발여부  ...  디스크위치  척추이동척도 척추전방위증  수술시간  수술실패여부  수술기법 흡연여부  Instability  \
# 0        0  ...      4    Down      0  68.0       0  TELD    0            0
# 1        0  ...      4      Up      0  31.0       0  TELD    0            0
# 2        0  ...      4    Down      0  78.0       0  TELD    0            0
# 3        0  ...      4    Down      0  73.0       0  TELD    0            0
# 4        0  ...      4      Up      0  29.0       0  TELD    0            0
# ...    ...  ...    ...     ...    ...   ...     ...   ...  ...          ...
# 1889     0  ...      5  Middle      0  80.0       0   NaN    0            0
# 1890     0  ...      4    Down      0  20.0       0   NaN    0            0
# 1891     0  ...      4    Down      0  50.0       0  IELD    0            0
# 1892     0  ...      5    Down      0  25.0       0   NaN    0            0
# 1893     0  ...      5  Middle      0  45.0       0   NaN    0            0
#
#         혈액형 입원기간
# 0      RH+A    2
# 1      RH+A    1
# 2      RH+B    1
# 3      RH+O    1
# 4      RH+A    2
# ...     ...  ...
# 1889   RH+A    2
# 1890   RH+B    4
# 1891   RH+O    3
# 1892   RH+A    4
# 1893  RH+AB    2
#
# [1894 rows x 21 columns]

# %%
df_ROSF.to_csv('./datasets/RecurrenceOfSurgery_Final.csv')
