# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font',family='Malgun Gothic')
import seaborn as sns
import pandas as pd
import scipy.stats as stats
import numpy as np

# %%
df_ROS = pd.read_csv('../../datasets/RecurrenceOfSurgery_Final.csv')
df_ROS[:2]
# Out:
#    Unnamed: 0 환자ID   신장    체중  연령  성별  Large Lymphocyte  우울증여부  종양진행여부  재발여부  \
# 0           0  1PT  163  60.3  66   2              22.8      0       0     0
# 1           1  2PT  171  71.7  47   1              44.9      0       0     0
#
#    ...  디스크위치  척추이동척도 척추전방위증  수술시간  수술실패여부  수술기법 흡연여부  Instability   혈액형 입원기간
# 0  ...      4    Down      0  68.0       0  TELD    0            0  RH+A    2
# 1  ...      4      Up      0  31.0       0  TELD    0            0  RH+A    1
#
# [2 rows x 21 columns]

# %% [markdown]
# #### 1. 목표변수 설정 ex)입원기간여부가 목표변수
# #### 2. non- null 전처리 필요 (확인이 필요)

# %%
df_ROS_Analysis = df_ROS[['입원기간','성별','우울증여부', '종양진행여부', '재발여부', '디스크위치', '척추전방위증','수술실패여부', '흡연여부']]

# %%
df_ROS_Analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1758 entries, 0 to 1757
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   입원기간    1758 non-null   int64
#  1   성별      1758 non-null   int64
#  2   우울증여부   1758 non-null   int64
#  3   종양진행여부  1758 non-null   int64
#  4   재발여부    1758 non-null   int64
#  5   디스크위치   1758 non-null   int64
#  6   척추전방위증  1758 non-null   int64
#  7   수술실패여부  1758 non-null   int64
#  8   흡연여부    1758 non-null   int64
# dtypes: int64(9)
# memory usage: 123.7 KB

# %%
## 전처리 확인필요  : 대상 컬럼에 의한 레코드 삭제 시 데이터셋의 양이 통계적인 분포도에 너무 적지 않은지 고려 
## 최소 50개 이상.
## 날짜가 들어가지 않으면 200~500개 사이면 삭제해도 가능
## 단)날짜가 들어갈 시 , 데이터양이 더 많아야 함 
df_ROS_Analysis = df_ROS_Analysis.dropna()
df_ROS_Analysis.isnull().sum()
# Out:
# 입원기간      0
# 성별        0
# 우울증여부     0
# 종양진행여부    0
# 재발여부      0
# 디스크위치     0
# 척추전방위증    0
# 수술실패여부    0
# 흡연여부      0
# dtype: int64

# %% [markdown]
# ### 상관관계  확인 필요 (스토리)
# - 목표변수 : '입원기간' - 분포 언발란스 (연속형: 정규화 확인, 범주형: 밸런스 확인유무)
# - 설명변수:
#     - '성별'     : 성별부분, 여성이 남성에 비해 입원 기간이 높은 것을 확인됨.
#     - '우울증여부'     : 우울증 확인 결과, 0에 가까울수록 입원기간이 길어진 것으로 확인됨.
#     - '종양진행여부': 0(종양없음)에 비해 1(종양있음) 가까울 수록 입원기간이 길어진 것을 확인함.
#     - '재발여부'     : 0>1에 비해 입원기간이 길어진 것으로 확인 되었음.
#     - '디스크위치' : 디스크위치가 12에 있을수록 입원기간이 길어진 것을 확인할 수 있음.
#     - '척추전방위증'     : 1에 가까울수록 입원기간이 길어진 것을 확인할 수 잇음 .
#     - '수술실패여부'     : 1에 가까울수록 입원기간이 상대적으로 길어진 것을 확인함.
#     - '흡연여부'   : 1에 가까울수록 입원기간이 길어진 것을 확인함.  (확증 데이터 분석)
#     - ※ 구체적인 통계적수치 및  증명은 CDA에서  보여줄 예정 .
#
# - 분석스토리 :

# %%
### 데이터 타입과 분포 
## 목표변수 확인 필요 : 대부분 범주형 why? 예측률이 높아야 하기에 분류를 많이 함. 
sns.histplot(data=df_ROS_Analysis, x='입원기간',kde=True)
plt.show()

# %%
for item in df_ROS_Analysis :
    sns.barplot(data=df_ROS, x=item , y='입원기간')
    plt.show()

# %%
df_ROS_list = df_ROS.describe().columns.to_list()
df_ROS_list
# Out:
# ['Unnamed: 0',
#  '신장',
#  '체중',
#  '연령',
#  '성별',
#  'Large Lymphocyte',
#  '우울증여부',
#  '종양진행여부',
#  '재발여부',
#  '디스크단면적',
#  '디스크위치',
#  '척추전방위증',
#  '수술시간',
#  '수술실패여부',
#  '흡연여부',
#  'Instability',
#  '입원기간']

# %% [markdown]
# #### 연속형 범주형

# %%
## boxplot/barplot으로 그리기. 
for item in df_ROS_Analysis :
    sns.boxplot(data=df_ROS, x=item, y='입원기간', orient='h')
    plt.show()
